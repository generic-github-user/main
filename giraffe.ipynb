# %%
import nltk
from fuzzywuzzy import fuzz
import string
import random
import itertools
import pprint
import pyvis
from IPython.display import JSON

# %%
hamlet = nltk.corpus.gutenberg.sents('shakespeare-hamlet.txt')
def words_to_sent(w):
    s = w[0]
    s += ''.join([t if t in string.punctuation else ' '+t for t in w[1:]])
    return s
hamlet = list(map(words_to_sent, hamlet))
hamlet = list(filter(lambda l: len(l) >= 10, hamlet))

# %%
len(hamlet)
# Out:
# 1912

# %%
pyvis.network.Network.add_node
# Out:
# <function pyvis.network.Network.add_node(self, n_id, label=None, shape='dot', **options)>

# %%
w = 800
def clip(x):
    return x[:20]

c = random.choices(hamlet, k=w*2)
a = c[:w]
b = c[w:]

a, b = map(clip, a), map(clip, b)
pairs = []
limit = 1000
for x, y in itertools.product(a, b):
    dist = fuzz.token_sort_ratio(x, y)
    if 60 < dist < 97:
        pairs.append([dist, x, y])
    if len(pairs) >= limit:
        break

pprinter = pprint.PrettyPrinter()
pprinter.pprint(pairs[:5])
print(len(pairs))
# Out:
# [[74, 'My Lord, my Lord.', 'My good Lord'],
#  [73, 'My Lord, my Lord.', 'No my good Lord'],
#  [65, 'My Lord, my Lord.', 'My Lord, you once di'],
#  [71, 'My Lord, my Lord.', 'Good my Lord, will y'],
#  [63, 'My Lord, my Lord.', 'Good my Lord tell it']]
# 1000

# %%
G.find(random.choice(G.nodes).value)
# Out:
# []

# %%
class Graph:
    def init(self, nodes=None):
        if nodes is None:
            nodes = []
        self.nodes = nodes
        
    def visualize(self, **kwargs):
        self.visualization = pyvis.network.Network(notebook=True, **kwargs)
        added_nodes = []
        for node in self.nodes:
            text = node.value
            if not node.grouped:
#                 print(node.degree())
                deg = node.degree()
                self.visualization.add_node(text, group=deg, size=10)#, size=deg**(1/4)*10)
#             for g in node.grouped:
#                 self.visualization.add_edge(text, g.value)
        for node in self.nodes:
            if len(node.grouped) == 2:
                d = int(10e2*1/(node.value*0.1))
#                 print([n.grouped for n in self.nodes])
                self.visualization.add_edge(*[x.value for x in node.grouped], length=d, label=node.value)
        return self.visualization.show('./visualization.html')
    
    def find(self, x):
        return list(filter(lambda n: n.value == x and n.unique, self.nodes))
    
    def add_node(self, data, duplicate=False, return_node=True):
        new_node = None
        if type(data) in [list, tuple]:
            matches = self.find(data[0])
            if (not matches) or duplicate:
                connecting_node = Node(data[0], data[1:], graph=self)
    #             self.nodes.append(connecting_node)
                self.add_node(connecting_node)
                new_node = connecting_node
            elif matches:
                new_node = matches[0]
        elif type(data) in [Node]:
            matches = self.find(data.value)
#             print(matches, data.value)
            if (not matches) or duplicate:
#             if not matches or type(data.value) is int:
                self.nodes.append(data)
                new_node = data
            elif matches:
                new_node = matches[0]
        elif type(data) in [str, int, float, bool]:
            matches = self.find(data)
            if (not matches) or duplicate:
                new_node = Node(data, graph=self)
            elif matches:
                new_node = matches[0]
        
        if return_node:
            return new_node
        else:
            return self
    
    def add_nodes(self, x):
        for xi in x:
            self.add_node(xi)
        return self
            
class Node:
    def init(self, value, grouped=None, graph=None):
        self.value = value
        if grouped is None:
            grouped = []
#         self.grouped = [g if type(g) is Node else Node(g, graph=graph) for g in grouped]
        self.graph = graph
        self.grouped = [g if type(g) is Node else self.graph.add_node(g) for g in grouped]
        self.unique = not (type(self.value) is int)
        if graph:
            graph.add_node(self)
            
    def degree(self):
        self.deg = None
        if self.graph:
#             self.deg = sum(int(self in x.grouped) for x in self.graph.nodes)
#             self.deg = sum(map(bool, self.graph.find(self.value)))
            self.deg = sum(self in x.grouped for x in self.graph.nodes)
#             print(self.deg)
        return self.deg
            
    def __str__(self):
        return str(self.value)
        
for cls in [Graph, Node]:
    setattr(cls, '__init__', getattr(cls, 'init'))
    

G = Graph()
G.add_nodes(pairs).nodes[0].value
G.visualize(width=1000, height=1000)

# Graph(rule=)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./visualization.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# G.nodes[35].grouped
# G.nodes
sorted(list(map(str, [list(map(str, g.grouped)) for g in G.nodes])), reverse=True)
# Out:
# ['[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  "['where is thy Blush?', 'Oh, how the wheele becomes it?']",
#  "['where is thy Blush?', 'Oh, how the wheele becomes it?']",
#  "['where is thy Blush?', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['where is thy Blush?', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  '[\'where is thy Blush?\', "He is iustly seru\' d."]',
#  '[\'where is thy Blush?\', "He is iustly seru\' d."]',
#  "['What are they that would speake with me?', 'What may this meane?']",
#  "['What are they that would speake with me?', 'What may this meane?']",
#  "['What are they that would speake with me?', 'Sweets, to the sweet farewell.']",
#  "['What are they that would speake with me?', 'Sweets, to the sweet farewell.']",
#  "['What are they that would speake with me?', 'And the Queene too, and that presently']",
#  "['What are they that would speake with me?', 'And the Queene too, and that presently']",
#  '[\'What are they that would speake with me?\', "Why would\' st thou be a breeder of Sinners?"]',
#  '[\'What are they that would speake with me?\', "Why would\' st thou be a breeder of Sinners?"]',
#  "['To the Celestiall, and my Soules Idoll, the most beautifed Ophelia.', 'Soft you now, The faire Ophelia?']",
#  "['To the Celestiall, and my Soules Idoll, the most beautifed Ophelia.', 'Soft you now, The faire Ophelia?']",
#  "['To the Celestiall, and my Soules Idoll, the most beautifed Ophelia.', 'Pretty Ophelia']",
#  "['To the Celestiall, and my Soules Idoll, the most beautifed Ophelia.', 'Pretty Ophelia']",
#  '[\'Something is rotten in the State of Denmarke\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '[\'Something is rotten in the State of Denmarke\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  "['O God, O God!', 'Oh God, your onely Iigge- maker: what should a man do, but be merrie.']",
#  "['O God, O God!', 'Oh God, your onely Iigge- maker: what should a man do, but be merrie.']",
#  "['O God, O God!', 'Oh God, your onely Iigge- maker: what should a man do, but be merrie.']",
#  "['O God, O God!', 'Oh God, your onely Iigge- maker: what should a man do, but be merrie.']",
#  "['O God, O God!', 'God blesse you Sir']",
#  "['O God, O God!', 'God blesse you Sir']",
#  "['It well appeares.', 'Prepare to play.']",
#  "['It well appeares.', 'Prepare to play.']",
#  '[\'It well appeares.\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '[\'It well appeares.\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '[\'It is a nipping and an eager ayre\', "Speake the Speech I pray you, as I pronounc\' d it to you trippingly on the Tongue: But if you mouth it, as many of your Players do, I had as liue the Town- Cryer had spoke my Lines: Nor do not saw the Ayre too much your hand thus, but vse all gently; for in the verie Torrent, Tempest, and( as I say) the Whirle- winde of Passion, you must acquire and beget a Temperance that may giue it Smoothnesse."]',
#  '[\'It is a nipping and an eager ayre\', "Speake the Speech I pray you, as I pronounc\' d it to you trippingly on the Tongue: But if you mouth it, as many of your Players do, I had as liue the Town- Cryer had spoke my Lines: Nor do not saw the Ayre too much your hand thus, but vse all gently; for in the verie Torrent, Tempest, and( as I say) the Whirle- winde of Passion, you must acquire and beget a Temperance that may giue it Smoothnesse."]',
#  '[\'It is a nipping and an eager ayre\', "He keepes them like an Ape in the corner of his iaw, first mouth\' d to be last swallowed, when he needes what you haue glean\' d, it is but squeezing you, and Spundge you shall be dry againe"]',
#  '[\'It is a nipping and an eager ayre\', "He keepes them like an Ape in the corner of his iaw, first mouth\' d to be last swallowed, when he needes what you haue glean\' d, it is but squeezing you, and Spundge you shall be dry againe"]',
#  "['I, good my Lord', 'These good Fellowes will bring thee where I am.']",
#  "['I, good my Lord', 'These good Fellowes will bring thee where I am.']",
#  "['I, good my Lord', 'Oh my olde Friend?']",
#  "['I, good my Lord', 'Oh my olde Friend?']",
#  "['I, good my Lord', 'O my Lord, if my Dutie be too bold, my loue is too vnmannerly']",
#  "['I, good my Lord', 'O my Lord, if my Dutie be too bold, my loue is too vnmannerly']",
#  "['I, good my Lord', 'My Lord, you once did loue me']",
#  "['I, good my Lord', 'My Lord, you once did loue me']",
#  "['I, good my Lord', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['I, good my Lord', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['I, good my Lord', 'I am to doe a good turne for them.']",
#  "['I, good my Lord', 'I am to doe a good turne for them.']",
#  "['I, good my Lord', 'Good my Lord, what is your cause of distemper?']",
#  "['I, good my Lord', 'Good my Lord, what is your cause of distemper?']",
#  '[\'I, good my Lord\', "I will doo\' t, my Lord"]',
#  '[\'I, good my Lord\', "I will doo\' t, my Lord"]',
#  '[\'I, good my Lord\', "Good Gentlemen, he hath much talk\' d of you, And sure I am, two men there are not liuing, To whom he more adheres."]',
#  '[\'I, good my Lord\', "Good Gentlemen, he hath much talk\' d of you, And sure I am, two men there are not liuing, To whom he more adheres."]',
#  "['I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.', 'My Mother you say']",
#  "['I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.', 'My Mother you say']",
#  "['I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.', 'Do you see that Clowd?']",
#  "['I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.', 'Do you see that Clowd?']",
#  '[\'I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.\', "Shall I redeliuer you ee\' n so?"]',
#  '[\'I would not haue your Enemy say so; Nor shall you doe mine eare that violence, To make it truster of your owne report Against your selfe.\', "Shall I redeliuer you ee\' n so?"]',
#  "['Exit Hamlet.', 'Exit Voltemand and Cornelius.']",
#  "['Exit Hamlet.', 'Exit Voltemand and Cornelius.']",
#  "['Euen those you were wont to take delight in the Tragedians of the City', 'Hold you the watch to Night?']",
#  "['Euen those you were wont to take delight in the Tragedians of the City', 'Hold you the watch to Night?']",
#  "['Euen those you were wont to take delight in the Tragedians of the City', 'Doe they hold the same estimation they did when I was in the City?']",
#  "['Euen those you were wont to take delight in the Tragedians of the City', 'Doe they hold the same estimation they did when I was in the City?']",
#  '[\'Euen those you were wont to take delight in the Tragedians of the City\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '[\'Euen those you were wont to take delight in the Tragedians of the City\', "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'King Dyes.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'King Dyes.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'Enter King, Queene, Polonius, Ophelia, Rosincrance, Guildenstern, and Lords.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'Enter King, Queene, Polonius, Ophelia, Rosincrance, Guildenstern, and Lords.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'Enter King and his Queene.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'Enter King and his Queene.']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'And the Queene too, and that presently']",
#  "['Enter a King and Queene, very louingly; the Queene embracing him.', 'And the Queene too, and that presently']",
#  "['Enter Polonius.', 'First, her Father slaine, Next your Sonne gone, and he most violent Author Of his owne iust remoue: the people muddied, Thicke and vnwholsome in their thoughts, and whispers For good Polonius death; and we haue done but greenly In hugger mugger to interre him.']",
#  "['Enter Polonius.', 'First, her Father slaine, Next your Sonne gone, and he most violent Author Of his owne iust remoue: the people muddied, Thicke and vnwholsome in their thoughts, and whispers For good Polonius death; and we haue done but greenly In hugger mugger to interre him.']",
#  "['Enter Polonius.', 'Enter foure or fiue Players.']",
#  "['Enter Polonius.', 'Enter foure or fiue Players.']",
#  "['Enter Polonius.', 'Enter Ophelia distracted.']",
#  "['Enter Polonius.', 'Enter Ophelia distracted.']",
#  "['Enter Polonius.', 'Enter King, Queene, Polonius, Ophelia, Rosincrance, Guildenstern, and Lords.']",
#  "['Enter Polonius.', 'Enter King, Queene, Polonius, Ophelia, Rosincrance, Guildenstern, and Lords.']",
#  "['Enter Polonius.', 'Enter King and his Queene.']",
#  "['Enter Polonius.', 'Enter King and his Queene.']",
#  "['Enter Horatio, Barnardo, and Marcellus.', 'Enter King and his Queene.']",
#  "['Enter Horatio, Barnardo, and Marcellus.', 'Enter King and his Queene.']",
#  "['Cannot you tell that?', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['Cannot you tell that?', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['Cannot you tell that?', 'Hold you the watch to Night?']",
#  "['Cannot you tell that?', 'Hold you the watch to Night?']",
#  "['Cannot you tell that?', 'Do you see that Clowd?']",
#  "['Cannot you tell that?', 'Do you see that Clowd?']",
#  "['Bring in my Lord.', 'My Lord, you once did loue me']",
#  "['Bring in my Lord.', 'My Lord, you once did loue me']",
#  "['Bring in my Lord.', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['Bring in my Lord.', 'My Lord, you must tell vs where the body is, and go with vs to the King']",
#  "['Bring in my Lord.', 'Good my Lord, what is your cause of distemper?']",
#  "['Bring in my Lord.', 'Good my Lord, what is your cause of distemper?']",
#  '[\'Bring in my Lord.\', "I will doo\' t, my Lord"]',
#  '[\'Bring in my Lord.\', "I will doo\' t, my Lord"]',
#  '[\'Aye me; what act, that roares so lowd,& thunders in the Index\', "O what a Noble minde is heere o\' re- throwne?"]',
#  '[\'Aye me; what act, that roares so lowd,& thunders in the Index\', "O what a Noble minde is heere o\' re- throwne?"]',
#  '["Y\' are welcome Masters, welcome all.", \'Welcome deere Rosincrance and Guildensterne.\']',
#  '["Y\' are welcome Masters, welcome all.", \'Welcome deere Rosincrance and Guildensterne.\']',
#  '["Y\' are welcome Masters, welcome all.", "Excellent, excellent well: y\' are a Fishmonger"]',
#  '["Y\' are welcome Masters, welcome all.", "Excellent, excellent well: y\' are a Fishmonger"]',
#  '["Wee\' l ha\' t to morrow night.", \'I am to doe a good turne for them.\']',
#  '["Wee\' l ha\' t to morrow night.", \'I am to doe a good turne for them.\']',
#  '["Wee\' l ha\' t to morrow night.", \'Hold you the watch to Night?\']',
#  '["Wee\' l ha\' t to morrow night.", \'Hold you the watch to Night?\']',
#  '["O Iephta Iudge of Israel, what a Treasure had\' st thou?", "O what a Noble minde is heere o\' re- throwne?"]',
#  '["O Iephta Iudge of Israel, what a Treasure had\' st thou?", "O what a Noble minde is heere o\' re- throwne?"]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'Why, what a King is this?\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'Why, what a King is this?\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'So much for him.\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'So much for him.\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'Hold you the watch to Night?\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'Hold you the watch to Night?\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'And the Queene too, and that presently\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", \'And the Queene too, and that presently\']',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "Pray loue remember: and there is Paconcies, that\' s for Thoughts"]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "Pray loue remember: and there is Paconcies, that\' s for Thoughts"]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land."]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "I see a Cherube that see\' s him: but come, for England."]',
#  '["Now sir, young Fortinbras, Of vnimproued Mettle, hot and full, Hath in the skirts of Norway, heere and there, Shark\' d vp a List of Landlesse Resolutes, For Foode and Diet, to some Enterprize That hath a stomacke in\' t: which is no other( And it doth well appeare vnto our State) But to recouer of vs by strong hand And termes Compulsatiue, those foresaid Lands So by his Father lost: and this( I take it) Is the maine Motiue of our Preparations, The Sourse of this our Watch, and the cheefe head Of this post- hast, and Romage in the Land.", "I see a Cherube that see\' s him: but come, for England."]',
#  '["Now Mother, what\' s the matter?", \'thou wilt not murther me?\']',
#  '["Now Mother, what\' s the matter?", \'thou wilt not murther me?\']',
#  '["Now Mother, what\' s the matter?", \'What may this meane?\']',
#  '["Now Mother, what\' s the matter?", \'What may this meane?\']',
#  '["Now Mother, what\' s the matter?", \'What hower now?\']',
#  '["Now Mother, what\' s the matter?", \'What hower now?\']',
#  '["Now Mother, what\' s the matter?", \'Soft you now, The faire Ophelia?\']',
#  '["Now Mother, what\' s the matter?", \'Soft you now, The faire Ophelia?\']',
#  '["Now Mother, what\' s the matter?", "O what a Noble minde is heere o\' re- throwne?"]',
#  '["Now Mother, what\' s the matter?", "O what a Noble minde is heere o\' re- throwne?"]',
#  '["Now Mother, what\' s the matter?", "But so much was our loue, We would not vnderstand what was most fit, But like the Owner of a foule disease, To keepe it from divulging, let\' s it feede Euen on the pith of life."]',
#  '["Now Mother, what\' s the matter?", "But so much was our loue, We would not vnderstand what was most fit, But like the Owner of a foule disease, To keepe it from divulging, let\' s it feede Euen on the pith of life."]',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'So much for him.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'So much for him.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Prepare to play.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Prepare to play.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Mother you say\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Mother you say\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Lord, you once did loue me\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Lord, you once did loue me\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Lord, you must tell vs where the body is, and go with vs to the King\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'My Lord, you must tell vs where the body is, and go with vs to the King\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Hold you the watch to Night?\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Hold you the watch to Night?\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Follow my Mother.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Follow my Mother.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Enter King and his Queene.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'Enter King and his Queene.\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'And the Queene too, and that presently\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", \'And the Queene too, and that presently\']',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", "Nay, let\' s follow him."]',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", "Nay, let\' s follow him."]',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", "I will doo\' t, my Lord"]',
#  '["My Lord, do as you please, But if you hold it fit after the Play, Let his Queene Mother all alone intreat him To shew his Greefes: let her be round with him, And Ile be plac\' d so, please you in the eare Of all their Conference.", "I will doo\' t, my Lord"]']

# %%
JSON(G.nodes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-5cbb600679cd> in <module>
# ----> 1 JSON(G.nodes)
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     264             self.fill_exec_result(result)
#     265             if format_dict:
# --> 266                 self.write_format_data(format_dict, md_dict)
#     267                 self.log_output(format_dict)
#     268             self.finish_displayhook()
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\ipykernel\displayhook.py in write_format_data(self, format_dict, md_dict)
#      69
#      70     def write_format_data(self, format_dict, md_dict=None):
# ---> 71         self.msg['content']['data'] = json_clean(encode_images(format_dict))
#      72         self.msg['content']['metadata'] = md_dict
#      73
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\ipykernel\jsonutil.py in <listcomp>(.0)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# c:\users\diamo\appdata\local\programs\python\python39\lib\site-packages\ipykernel\jsonutil.py in json_clean(obj)
#     149
#     150     # we don't understand it, it's probably an unserializable object
# --> 151     raise ValueError("Can't clean for JSON: %r" % obj)
#
# ValueError: Can't clean for JSON: <__main__.Node object at 0x00000197EE70B0A0>
